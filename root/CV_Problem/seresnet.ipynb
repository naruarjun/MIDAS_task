# %% [markdown]
# # SE-ResNet Implementation

# %%
from __future__ import print_function
from __future__ import absolute_import
from __future__ import division
from keras.models import Model
from keras.layers import *
from keras.regularizers import l2
from keras.utils import conv_utils
from keras.utils.data_utils import get_file
from keras.engine.topology import get_source_inputs
from keras_applications.imagenet_utils import _obtain_input_shape
from keras_applications.resnet50 import preprocess_input
from keras_applications.imagenet_utils import decode_predictions
from keras import backend as K
from datetime import datetime
from keras.preprocessing.image import ImageDataGenerator
from visualization import *
import time
from keras.optimizers import SGD,Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
import numpy as np 
import pandas as pd
from keras.utils import to_categorical

# %% [markdown]
# Here we create out squeeze excite block, this is the main contribution of the paper and adds a global average pooling and 2 dense layers after the normal resnet block

# %%
#two parameters: input and reduction ratio
def squeeze_excite_block(input, ratio=16):
    filter_kernels = input._keras_shape[-1]
    z_shape = (1, 1, filter_kernels)
    z = GlobalAveragePooling2D()(input)
    z = Reshape(z_shape)(z)
    s = Dense(filter_kernels//ratio, activation='relu', use_bias=False)(z)
    s = Dense(filter_kernels, activation='sigmoid', use_bias=False)(s)
    x = multiply([input, s])
    return x

# %% [markdown]
# Here we create out final netwokr block which is basically a bottleneck resnet block followed by the squeeze and excite block

# %%
def se_resnet_block_bottleneck(input,channels,_strides=(1, 1)):
    chan_axis=-1
    if(input._keras_shape[-1]!=channels or _strides!=(1,1)):
        input = Conv2D(channels, (1, 1), padding='same', kernel_initializer='he_normal',
                      use_bias=False, strides=_strides)(input)
    
    x = Conv2D(channels, (1, 1), padding='same', kernel_initializer='he_normal',
                      use_bias=False, strides=_strides)(input)
    x = BatchNormalization(axis=chan_axis)(x)
    x = Activation('relu')(x)
    
    
    x = Conv2D(channels, (3, 3), padding='same', kernel_initializer='he_normal',
                      use_bias=False, strides=_strides)(x)
    x = BatchNormalization(axis=chan_axis)(x)
    x = Activation('relu')(x)
    
    
    x = Conv2D(channels, (1, 1), padding='same', kernel_initializer='he_normal',
                      use_bias=False, strides=_strides)(x)
    x = BatchNormalization(axis=chan_axis)(x)
    x = Activation('relu')(x)
    
    
    x = squeeze_excite_block(x)
    out = add([x, input])
    return out

# %% [markdown]
# Here we implement the architecture given in the paper diagram using for loops and adding blocks continuously

# %%
def se_resnet(input,filters = [64,128,256,256,512],depth = [6,8,12,8,6],num_classes=4, weight_decay=1e-4):
# def se_resnet(input,filters = [64,128,256],depth = [6,8,6],num_classes=4, weight_decay=1e-4):
    chan_axis=-1
    x = Conv2D(filters[0], (3, 3), padding='same', use_bias=False, strides=(2, 2),
               kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(input)
    x = MaxPooling2D(pool_size=(2,2))(x)
    for i in range(len(filters)):
        x = se_resnet_block_bottleneck(x,filters[i],(2,2))
        for j in range(depth[i]-1):
            x = se_resnet_block_bottleneck(x,filters[i],(1,1))
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.85)(x)
    x = Dense(num_classes, activation='softmax', use_bias=False)(x)
    return x

# %% [markdown]
# Load the MNIST dataset here and create the create_model function that just uses the functions above to create our final model and return it.

# %%
import pickle
with open('./train_image.pkl', 'rb') as f:
    train_x = pickle.load(f,encoding='utf-8')
with open('./train_label.pkl', 'rb') as f:
    train_y = pickle.load(f,encoding='utf-8')
train_x = np.array(train_x).reshape(-1,28,28,1)
labels = np.array(train_y)
labels[labels==2]=1
labels[labels==3]=2
labels[labels==6]=3
train_y = np.zeros((labels.shape[0], 4))
train_y[np.arange(labels.shape[0]),labels] = 1

# %%
#train_x = np.expand_dims(train_x,axis=3)
#train_y = np.expand_dims(train_y,axis=1)
#train_y = to_categorical(train_y)
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
train_x, train_y = shuffle(train_x, train_y, random_state=0)
train_x, test_x, train_y, test_y = train_test_split(train_x, train_y, test_size=0.10, random_state=42)

def create_model(input_shape = (28, 28, 1),filters = [64,128,256,256,512],depth = [6,8,12,8,6],num_classes=4, weight_decay=1e-4):
#def create_model(input_shape = (28, 28, 1),filters = [64,128,256],depth = [6,8,6],num_classes=4, weight_decay=1e-4):
    input = Input(shape = input_shape)
    x = se_resnet(input,filters,depth,num_classes)
    model = Model(input, x)
    print(model.summary())
    return model

# %%
print(train_x.shape)
print(train_y.shape)
# Out:
# (7200, 28, 28, 1)
# (7200, 4)

# %% [markdown]
# Creating the model and printing the architecture

# %%
model = create_model()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 14, 14, 64)   576         input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 64)     0           conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 4, 4, 64)     4096        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 2, 2, 64)     4096        conv2d_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 2, 2, 64)     256         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 2, 2, 64)     0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 1, 1, 64)     36864       activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 1, 1, 64)     256         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 1, 1, 64)     0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 1, 1, 64)     4096        activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 1, 1, 64)     256         conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 1, 1, 64)     0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_42 (Gl (None, 64)           0           activation_123[0][0]
# __________________________________________________________________________________________________
# reshape_41 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 1, 1, 4)      256         reshape_41[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 1, 1, 64)     256         dense_82[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 1, 1, 64)     0           activation_123[0][0]
#                                                                  dense_83[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 4, 4, 64)     0           multiply_41[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 4, 4, 64)     4096        add_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 4, 4, 64)     256         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 4, 4, 64)     0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 4, 4, 64)     36864       activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 4, 4, 64)     256         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 4, 4, 64)     0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 4, 4, 64)     4096        activation_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 4, 4, 64)     256         conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 4, 4, 64)     0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_43 (Gl (None, 64)           0           activation_126[0][0]
# __________________________________________________________________________________________________
# reshape_42 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 1, 1, 4)      256         reshape_42[0][0]
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 1, 1, 64)     256         dense_84[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 4, 4, 64)     0           activation_126[0][0]
#                                                                  dense_85[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 4, 4, 64)     0           multiply_42[0][0]
#                                                                  add_41[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 4, 4, 64)     4096        add_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 4, 4, 64)     256         conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 4, 4, 64)     0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 4, 4, 64)     36864       activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 4, 4, 64)     256         conv2d_136[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 4, 4, 64)     0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 4, 4, 64)     4096        activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 4, 4, 64)     256         conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 4, 4, 64)     0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_44 (Gl (None, 64)           0           activation_129[0][0]
# __________________________________________________________________________________________________
# reshape_43 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# dense_86 (Dense)                (None, 1, 1, 4)      256         reshape_43[0][0]
# __________________________________________________________________________________________________
# dense_87 (Dense)                (None, 1, 1, 64)     256         dense_86[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 4, 4, 64)     0           activation_129[0][0]
#                                                                  dense_87[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 4, 4, 64)     0           multiply_43[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 4, 4, 64)     4096        add_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 4, 4, 64)     256         conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 4, 4, 64)     0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 4, 4, 64)     36864       activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 4, 4, 64)     256         conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 4, 4, 64)     0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 4, 4, 64)     4096        activation_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 4, 4, 64)     256         conv2d_140[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 4, 4, 64)     0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_45 (Gl (None, 64)           0           activation_132[0][0]
# __________________________________________________________________________________________________
# reshape_44 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# dense_88 (Dense)                (None, 1, 1, 4)      256         reshape_44[0][0]
# __________________________________________________________________________________________________
# dense_89 (Dense)                (None, 1, 1, 64)     256         dense_88[0][0]
# __________________________________________________________________________________________________
# multiply_44 (Multiply)          (None, 4, 4, 64)     0           activation_132[0][0]
#                                                                  dense_89[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 4, 4, 64)     0           multiply_44[0][0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 4, 4, 64)     4096        add_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 4, 4, 64)     256         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 4, 4, 64)     0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 4, 4, 64)     36864       activation_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 4, 4, 64)     256         conv2d_142[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 4, 4, 64)     0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 4, 4, 64)     4096        activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 4, 4, 64)     256         conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 4, 4, 64)     0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_46 (Gl (None, 64)           0           activation_135[0][0]
# __________________________________________________________________________________________________
# reshape_45 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# dense_90 (Dense)                (None, 1, 1, 4)      256         reshape_45[0][0]
# __________________________________________________________________________________________________
# dense_91 (Dense)                (None, 1, 1, 64)     256         dense_90[0][0]
# __________________________________________________________________________________________________
# multiply_45 (Multiply)          (None, 4, 4, 64)     0           activation_135[0][0]
#                                                                  dense_91[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 4, 4, 64)     0           multiply_45[0][0]
#                                                                  add_44[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 4, 4, 64)     4096        add_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 4, 4, 64)     256         conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 4, 4, 64)     0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 4, 4, 64)     36864       activation_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 4, 4, 64)     256         conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 4, 4, 64)     0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 4, 4, 64)     4096        activation_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 4, 4, 64)     256         conv2d_146[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 4, 4, 64)     0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_47 (Gl (None, 64)           0           activation_138[0][0]
# __________________________________________________________________________________________________
# reshape_46 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# dense_92 (Dense)                (None, 1, 1, 4)      256         reshape_46[0][0]
# __________________________________________________________________________________________________
# dense_93 (Dense)                (None, 1, 1, 64)     256         dense_92[0][0]
# __________________________________________________________________________________________________
# multiply_46 (Multiply)          (None, 4, 4, 64)     0           activation_138[0][0]
#                                                                  dense_93[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 4, 4, 64)     0           multiply_46[0][0]
#                                                                  add_45[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 2, 2, 128)    8192        add_46[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 1, 1, 128)    16384       conv2d_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 1, 1, 128)    512         conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 1, 1, 128)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 1, 1, 128)    147456      activation_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 1, 1, 128)    512         conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 1, 1, 128)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 1, 1, 128)    16384       activation_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 1, 1, 128)    512         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 1, 1, 128)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_48 (Gl (None, 128)          0           activation_141[0][0]
# __________________________________________________________________________________________________
# reshape_47 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# dense_94 (Dense)                (None, 1, 1, 8)      1024        reshape_47[0][0]
# __________________________________________________________________________________________________
# dense_95 (Dense)                (None, 1, 1, 128)    1024        dense_94[0][0]
# __________________________________________________________________________________________________
# multiply_47 (Multiply)          (None, 1, 1, 128)    0           activation_141[0][0]
#                                                                  dense_95[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 2, 2, 128)    0           multiply_47[0][0]
#                                                                  conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 2, 2, 128)    16384       add_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 2, 2, 128)    512         conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 2, 2, 128)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 2, 2, 128)    147456      activation_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 2, 2, 128)    512         conv2d_152[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 2, 2, 128)    0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 2, 2, 128)    16384       activation_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 2, 2, 128)    512         conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 2, 2, 128)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_49 (Gl (None, 128)          0           activation_144[0][0]
# __________________________________________________________________________________________________
# reshape_48 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# dense_96 (Dense)                (None, 1, 1, 8)      1024        reshape_48[0][0]
# __________________________________________________________________________________________________
# dense_97 (Dense)                (None, 1, 1, 128)    1024        dense_96[0][0]
# __________________________________________________________________________________________________
# multiply_48 (Multiply)          (None, 2, 2, 128)    0           activation_144[0][0]
#                                                                  dense_97[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 2, 2, 128)    0           multiply_48[0][0]
#                                                                  add_47[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 2, 2, 128)    16384       add_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 2, 2, 128)    512         conv2d_154[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 2, 2, 128)    0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 2, 2, 128)    147456      activation_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 2, 2, 128)    512         conv2d_155[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 2, 2, 128)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 2, 2, 128)    16384       activation_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 2, 2, 128)    512         conv2d_156[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 2, 2, 128)    0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_50 (Gl (None, 128)          0           activation_147[0][0]
# __________________________________________________________________________________________________
# reshape_49 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# dense_98 (Dense)                (None, 1, 1, 8)      1024        reshape_49[0][0]
# __________________________________________________________________________________________________
# dense_99 (Dense)                (None, 1, 1, 128)    1024        dense_98[0][0]
# __________________________________________________________________________________________________
# multiply_49 (Multiply)          (None, 2, 2, 128)    0           activation_147[0][0]
#                                                                  dense_99[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 2, 2, 128)    0           multiply_49[0][0]
#                                                                  add_48[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 2, 2, 128)    16384       add_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 2, 2, 128)    512         conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 2, 2, 128)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 2, 2, 128)    147456      activation_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 2, 2, 128)    512         conv2d_158[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 2, 2, 128)    0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 2, 2, 128)    16384       activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 2, 2, 128)    512         conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 2, 2, 128)    0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_51 (Gl (None, 128)          0           activation_150[0][0]
# __________________________________________________________________________________________________
# reshape_50 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# dense_100 (Dense)               (None, 1, 1, 8)      1024        reshape_50[0][0]
# __________________________________________________________________________________________________
# dense_101 (Dense)               (None, 1, 1, 128)    1024        dense_100[0][0]
# __________________________________________________________________________________________________
# multiply_50 (Multiply)          (None, 2, 2, 128)    0           activation_150[0][0]
#                                                                  dense_101[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 2, 2, 128)    0           multiply_50[0][0]
#                                                                  add_49[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 2, 2, 128)    16384       add_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 2, 2, 128)    512         conv2d_160[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 2, 2, 128)    0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 2, 2, 128)    147456      activation_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 2, 2, 128)    512         conv2d_161[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 2, 2, 128)    0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 2, 2, 128)    16384       activation_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 2, 2, 128)    512         conv2d_162[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 2, 2, 128)    0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_52 (Gl (None, 128)          0           activation_153[0][0]
# __________________________________________________________________________________________________
# reshape_51 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_52[0][0]
# __________________________________________________________________________________________________
# dense_102 (Dense)               (None, 1, 1, 8)      1024        reshape_51[0][0]
# __________________________________________________________________________________________________
# dense_103 (Dense)               (None, 1, 1, 128)    1024        dense_102[0][0]
# __________________________________________________________________________________________________
# multiply_51 (Multiply)          (None, 2, 2, 128)    0           activation_153[0][0]
#                                                                  dense_103[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 2, 2, 128)    0           multiply_51[0][0]
#                                                                  add_50[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 2, 2, 128)    16384       add_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 2, 2, 128)    512         conv2d_163[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 2, 2, 128)    0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 2, 2, 128)    147456      activation_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 2, 2, 128)    512         conv2d_164[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 2, 2, 128)    0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 2, 2, 128)    16384       activation_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 2, 2, 128)    512         conv2d_165[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 2, 2, 128)    0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_53 (Gl (None, 128)          0           activation_156[0][0]
# __________________________________________________________________________________________________
# reshape_52 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# dense_104 (Dense)               (None, 1, 1, 8)      1024        reshape_52[0][0]
# __________________________________________________________________________________________________
# dense_105 (Dense)               (None, 1, 1, 128)    1024        dense_104[0][0]
# __________________________________________________________________________________________________
# multiply_52 (Multiply)          (None, 2, 2, 128)    0           activation_156[0][0]
#                                                                  dense_105[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 2, 2, 128)    0           multiply_52[0][0]
#                                                                  add_51[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 2, 2, 128)    16384       add_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 2, 2, 128)    512         conv2d_166[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 2, 2, 128)    0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 2, 2, 128)    147456      activation_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 2, 2, 128)    512         conv2d_167[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 2, 2, 128)    0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 2, 2, 128)    16384       activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 2, 2, 128)    512         conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 2, 2, 128)    0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_54 (Gl (None, 128)          0           activation_159[0][0]
# __________________________________________________________________________________________________
# reshape_53 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# dense_106 (Dense)               (None, 1, 1, 8)      1024        reshape_53[0][0]
# __________________________________________________________________________________________________
# dense_107 (Dense)               (None, 1, 1, 128)    1024        dense_106[0][0]
# __________________________________________________________________________________________________
# multiply_53 (Multiply)          (None, 2, 2, 128)    0           activation_159[0][0]
#                                                                  dense_107[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 2, 2, 128)    0           multiply_53[0][0]
#                                                                  add_52[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 2, 2, 128)    16384       add_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 2, 2, 128)    512         conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 2, 2, 128)    0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 2, 2, 128)    147456      activation_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 2, 2, 128)    512         conv2d_170[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 2, 2, 128)    0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 2, 2, 128)    16384       activation_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 2, 2, 128)    512         conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 2, 2, 128)    0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_55 (Gl (None, 128)          0           activation_162[0][0]
# __________________________________________________________________________________________________
# reshape_54 (Reshape)            (None, 1, 1, 128)    0           global_average_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# dense_108 (Dense)               (None, 1, 1, 8)      1024        reshape_54[0][0]
# __________________________________________________________________________________________________
# dense_109 (Dense)               (None, 1, 1, 128)    1024        dense_108[0][0]
# __________________________________________________________________________________________________
# multiply_54 (Multiply)          (None, 2, 2, 128)    0           activation_162[0][0]
#                                                                  dense_109[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 2, 2, 128)    0           multiply_54[0][0]
#                                                                  add_53[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 1, 1, 256)    32768       add_54[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 1, 1, 256)    65536       conv2d_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 1, 1, 256)    1024        conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 1, 1, 256)    0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 1, 1, 256)    589824      activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 1, 1, 256)    1024        conv2d_174[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 1, 1, 256)    0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 1, 1, 256)    65536       activation_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 1, 1, 256)    1024        conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 1, 1, 256)    0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_56 (Gl (None, 256)          0           activation_165[0][0]
# __________________________________________________________________________________________________
# reshape_55 (Reshape)            (None, 1, 1, 256)    0           global_average_pooling2d_56[0][0]
# ...
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 1, 1, 512)    2048        conv2d_239[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 1, 1, 512)    0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 1, 1, 512)    262144      activation_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 1, 1, 512)    2048        conv2d_240[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 1, 1, 512)    0           batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_77 (Gl (None, 512)          0           activation_228[0][0]
# __________________________________________________________________________________________________
# reshape_76 (Reshape)            (None, 1, 1, 512)    0           global_average_pooling2d_77[0][0]
# __________________________________________________________________________________________________
# dense_152 (Dense)               (None, 1, 1, 32)     16384       reshape_76[0][0]
# __________________________________________________________________________________________________
# dense_153 (Dense)               (None, 1, 1, 512)    16384       dense_152[0][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 1, 1, 512)    0           activation_228[0][0]
#                                                                  dense_153[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 1, 1, 512)    0           multiply_76[0][0]
#                                                                  add_75[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 1, 1, 512)    262144      add_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 1, 1, 512)    2048        conv2d_241[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 1, 1, 512)    0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 1, 1, 512)    2359296     activation_229[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 1, 1, 512)    2048        conv2d_242[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 1, 1, 512)    0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 1, 1, 512)    262144      activation_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 1, 1, 512)    2048        conv2d_243[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 1, 1, 512)    0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_78 (Gl (None, 512)          0           activation_231[0][0]
# __________________________________________________________________________________________________
# reshape_77 (Reshape)            (None, 1, 1, 512)    0           global_average_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# dense_154 (Dense)               (None, 1, 1, 32)     16384       reshape_77[0][0]
# __________________________________________________________________________________________________
# dense_155 (Dense)               (None, 1, 1, 512)    16384       dense_154[0][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 1, 1, 512)    0           activation_231[0][0]
#                                                                  dense_155[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 1, 1, 512)    0           multiply_77[0][0]
#                                                                  add_76[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 1, 1, 512)    262144      add_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 1, 1, 512)    2048        conv2d_244[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 1, 1, 512)    0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 1, 1, 512)    2359296     activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 1, 1, 512)    2048        conv2d_245[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 1, 1, 512)    0           batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 1, 1, 512)    262144      activation_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 1, 1, 512)    2048        conv2d_246[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 1, 1, 512)    0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_79 (Gl (None, 512)          0           activation_234[0][0]
# __________________________________________________________________________________________________
# reshape_78 (Reshape)            (None, 1, 1, 512)    0           global_average_pooling2d_79[0][0]
# __________________________________________________________________________________________________
# dense_156 (Dense)               (None, 1, 1, 32)     16384       reshape_78[0][0]
# __________________________________________________________________________________________________
# dense_157 (Dense)               (None, 1, 1, 512)    16384       dense_156[0][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 1, 1, 512)    0           activation_234[0][0]
#                                                                  dense_157[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 1, 1, 512)    0           multiply_78[0][0]
#                                                                  add_77[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 1, 1, 512)    262144      add_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 1, 1, 512)    2048        conv2d_247[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 1, 1, 512)    0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 1, 1, 512)    2359296     activation_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 1, 1, 512)    2048        conv2d_248[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 1, 1, 512)    0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 1, 1, 512)    262144      activation_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 1, 1, 512)    2048        conv2d_249[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 1, 1, 512)    0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_80 (Gl (None, 512)          0           activation_237[0][0]
# __________________________________________________________________________________________________
# reshape_79 (Reshape)            (None, 1, 1, 512)    0           global_average_pooling2d_80[0][0]
# __________________________________________________________________________________________________
# dense_158 (Dense)               (None, 1, 1, 32)     16384       reshape_79[0][0]
# __________________________________________________________________________________________________
# dense_159 (Dense)               (None, 1, 1, 512)    16384       dense_158[0][0]
# __________________________________________________________________________________________________
# multiply_79 (Multiply)          (None, 1, 1, 512)    0           activation_237[0][0]
#                                                                  dense_159[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 1, 1, 512)    0           multiply_79[0][0]
#                                                                  add_78[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 1, 1, 512)    262144      add_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 1, 1, 512)    2048        conv2d_250[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 1, 1, 512)    0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 1, 1, 512)    2359296     activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 1, 1, 512)    2048        conv2d_251[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 1, 1, 512)    0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 1, 1, 512)    262144      activation_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 1, 1, 512)    2048        conv2d_252[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 1, 1, 512)    0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_81 (Gl (None, 512)          0           activation_240[0][0]
# __________________________________________________________________________________________________
# reshape_80 (Reshape)            (None, 1, 1, 512)    0           global_average_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# dense_160 (Dense)               (None, 1, 1, 32)     16384       reshape_80[0][0]
# __________________________________________________________________________________________________
# dense_161 (Dense)               (None, 1, 1, 512)    16384       dense_160[0][0]
# __________________________________________________________________________________________________
# multiply_80 (Multiply)          (None, 1, 1, 512)    0           activation_240[0][0]
#                                                                  dense_161[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 1, 1, 512)    0           multiply_80[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_82 (Gl (None, 512)          0           add_80[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           global_average_pooling2d_82[0][0]
# __________________________________________________________________________________________________
# dense_162 (Dense)               (None, 4)            2048        dropout_1[0][0]
# ==================================================================================================
# Total params: 34,170,944
# Trainable params: 34,113,344
# Non-trainable params: 57,600
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Basic Training code

# %%
#model_filename:where the model is checkpointed
from random_eraser import get_random_eraser
datagen = ImageDataGenerator(featurewise_center=True,featurewise_std_normalization=True,preprocessing_function=get_random_eraser(v_l=0, v_h=1))
datagen.fit(train_x)
model_id = 1
model_dir = './runs1'
timestr = time.strftime("%Y%m%d-%H%M%S")
model_filename = model_dir + '{}-{}.hdf5'.format(model_id, timestr)
print('model checkpoint file path: {}'.format(model_filename))
lr_reduction_factor = 0.2
min_learning_rate = 1e-07
#Adding early stopping,model_checkpoint,reduceLRonPlateau
early_stop = EarlyStopping(monitor='val_loss',
                           patience=3,
                           min_delta=0, 
                           verbose=1,
                           mode='auto')

model_checkpoint = ModelCheckpoint(model_filename,
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True)

reduceLR = ReduceLROnPlateau(monitor='val_loss',
                             factor=lr_reduction_factor,
                             patience=2,
                             verbose=1,
                             min_lr=min_learning_rate,
                             epsilon=1e-4)
training_start_time = datetime.now()
model.compile(optimizer=Adam(1e-4),loss="categorical_crossentropy",metrics=["accuracy"])
history = model.fit_generator(datagen.flow(train_x,train_y,batch_size=16,shuffle=True),epochs=100,verbose=1,callbacks=[model_checkpoint],shuffle=True,validation_data=datagen.flow(test_x,test_y,batch_size=16,shuffle=True))
time_spent_trianing = datetime.now() - training_start_time
print('model training complete. time spent: {}'.format(time_spent_trianing))
# Out:
# model checkpoint file path: ./runs11-20190322-022352.hdf5
# /usr/local/lib/python3.5/dist-packages/keras/callbacks.py:999: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Epoch 1/100
# 450/450 [==============================] - 115s 255ms/step - loss: 8.1906 - acc: 0.4372 - val_loss: 5.4954 - val_acc: 0.6000
#
# Epoch 00001: val_loss improved from inf to 5.49540, saving model to ./runs11-20190322-022352.hdf5
# Epoch 2/100
# 450/450 [==============================] - 73s 162ms/step - loss: 5.7087 - acc: 0.6033 - val_loss: 4.3648 - val_acc: 0.6837
#
# Epoch 00002: val_loss improved from 5.49540 to 4.36482, saving model to ./runs11-20190322-022352.hdf5
# Epoch 3/100
# 450/450 [==============================] - 74s 164ms/step - loss: 5.1171 - acc: 0.6508 - val_loss: 4.3157 - val_acc: 0.7087
#
# Epoch 00003: val_loss improved from 4.36482 to 4.31566, saving model to ./runs11-20190322-022352.hdf5
# Epoch 4/100
# 450/450 [==============================] - 72s 161ms/step - loss: 4.7317 - acc: 0.6771 - val_loss: 4.1829 - val_acc: 0.7063
#
# Epoch 00004: val_loss improved from 4.31566 to 4.18290, saving model to ./runs11-20190322-022352.hdf5
# Epoch 5/100
# 450/450 [==============================] - 72s 160ms/step - loss: 4.4628 - acc: 0.7014 - val_loss: 3.9217 - val_acc: 0.7312
#
# Epoch 00005: val_loss improved from 4.18290 to 3.92172, saving model to ./runs11-20190322-022352.hdf5
# Epoch 6/100
# 450/450 [==============================] - 74s 163ms/step - loss: 4.3937 - acc: 0.7056 - val_loss: 3.9729 - val_acc: 0.7325
#
# Epoch 00006: val_loss did not improve from 3.92172
# Epoch 7/100
# 450/450 [==============================] - 72s 161ms/step - loss: 4.3022 - acc: 0.7156 - val_loss: 3.7337 - val_acc: 0.7562
#
# Epoch 00007: val_loss improved from 3.92172 to 3.73374, saving model to ./runs11-20190322-022352.hdf5
# Epoch 8/100
# 450/450 [==============================] - 72s 161ms/step - loss: 4.2331 - acc: 0.7163 - val_loss: 4.0334 - val_acc: 0.7312
#
# Epoch 00008: val_loss did not improve from 3.73374
# Epoch 9/100
# 450/450 [==============================] - 72s 160ms/step - loss: 4.2009 - acc: 0.7250 - val_loss: 3.7771 - val_acc: 0.7538
#
# Epoch 00009: val_loss did not improve from 3.73374
# Epoch 10/100
# 450/450 [==============================] - 73s 162ms/step - loss: 4.3036 - acc: 0.7178 - val_loss: 3.9872 - val_acc: 0.7325
#
# Epoch 00010: val_loss did not improve from 3.73374
# Epoch 11/100
# 450/450 [==============================] - 73s 162ms/step - loss: 3.9542 - acc: 0.7403 - val_loss: 3.8075 - val_acc: 0.7475
#
# Epoch 00011: val_loss did not improve from 3.73374
# Epoch 12/100
# 450/450 [==============================] - 73s 162ms/step - loss: 4.0570 - acc: 0.7375 - val_loss: 3.9629 - val_acc: 0.7375
#
# Epoch 00012: val_loss did not improve from 3.73374
# Epoch 13/100
# 450/450 [==============================] - 74s 164ms/step - loss: 4.0044 - acc: 0.7410 - val_loss: 4.8590 - val_acc: 0.6850
#
# Epoch 00013: val_loss did not improve from 3.73374
# Epoch 14/100
# 450/450 [==============================] - 73s 163ms/step - loss: 4.0760 - acc: 0.7371 - val_loss: 4.0694 - val_acc: 0.7375
#
# Epoch 00014: val_loss did not improve from 3.73374
# Epoch 15/100
# 450/450 [==============================] - 73s 162ms/step - loss: 4.1078 - acc: 0.7360 - val_loss: 3.9611 - val_acc: 0.7450
#
# Epoch 00015: val_loss did not improve from 3.73374
# Epoch 16/100
# 450/450 [==============================] - 73s 163ms/step - loss: 3.8859 - acc: 0.7493 - val_loss: 3.9052 - val_acc: 0.7475
#
# Epoch 00016: val_loss did not improve from 3.73374
# Epoch 17/100
# 450/450 [==============================] - 73s 163ms/step - loss: 3.9857 - acc: 0.7421 - val_loss: 3.7369 - val_acc: 0.7575
#
# Epoch 00017: val_loss did not improve from 3.73374
# Epoch 18/100
# 450/450 [==============================] - 73s 162ms/step - loss: 3.8796 - acc: 0.7481 - val_loss: 3.6503 - val_acc: 0.7625
#
# Epoch 00018: val_loss improved from 3.73374 to 3.65028, saving model to ./runs11-20190322-022352.hdf5
# Epoch 19/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.7551 - acc: 0.7589 - val_loss: 3.6026 - val_acc: 0.7688
#
# Epoch 00019: val_loss improved from 3.65028 to 3.60256, saving model to ./runs11-20190322-022352.hdf5
# Epoch 20/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.6885 - acc: 0.7618 - val_loss: 3.6603 - val_acc: 0.7625
#
# Epoch 00020: val_loss did not improve from 3.60256
# Epoch 21/100
# 450/450 [==============================] - 73s 163ms/step - loss: 3.8803 - acc: 0.7526 - val_loss: 3.8939 - val_acc: 0.7500
#
# Epoch 00021: val_loss did not improve from 3.60256
# Epoch 22/100
# 450/450 [==============================] - 73s 163ms/step - loss: 3.7711 - acc: 0.7582 - val_loss: 3.6426 - val_acc: 0.7675
#
# Epoch 00022: val_loss did not improve from 3.60256
# Epoch 23/100
# 450/450 [==============================] - 72s 160ms/step - loss: 3.8377 - acc: 0.7539 - val_loss: 3.8049 - val_acc: 0.7525
#
# Epoch 00023: val_loss did not improve from 3.60256
# Epoch 24/100
# 450/450 [==============================] - 72s 160ms/step - loss: 3.7277 - acc: 0.7625 - val_loss: 3.5827 - val_acc: 0.7688
#
# Epoch 00024: val_loss improved from 3.60256 to 3.58266, saving model to ./runs11-20190322-022352.hdf5
# Epoch 25/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.7845 - acc: 0.7576 - val_loss: 3.9729 - val_acc: 0.7462
#
# Epoch 00025: val_loss did not improve from 3.58266
# Epoch 26/100
# 450/450 [==============================] - 72s 160ms/step - loss: 3.7433 - acc: 0.7622 - val_loss: 3.7826 - val_acc: 0.7638
#
# Epoch 00026: val_loss did not improve from 3.58266
# Epoch 27/100
# 450/450 [==============================] - 72s 160ms/step - loss: 3.7270 - acc: 0.7633 - val_loss: 4.2136 - val_acc: 0.7300
#
# Epoch 00027: val_loss did not improve from 3.58266
# Epoch 28/100
# 450/450 [==============================] - 72s 160ms/step - loss: 3.8428 - acc: 0.7549 - val_loss: 3.7958 - val_acc: 0.7575
#
# Epoch 00028: val_loss did not improve from 3.58266
# Epoch 29/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.6385 - acc: 0.7683 - val_loss: 3.8193 - val_acc: 0.7562
#
# Epoch 00029: val_loss did not improve from 3.58266
# Epoch 30/100
# 450/450 [==============================] - 73s 161ms/step - loss: 3.6185 - acc: 0.7707 - val_loss: 3.7848 - val_acc: 0.7612
#
# Epoch 00030: val_loss did not improve from 3.58266
# Epoch 31/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.8280 - acc: 0.7576 - val_loss: 4.1070 - val_acc: 0.7400
#
# Epoch 00031: val_loss did not improve from 3.58266
# Epoch 32/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.7205 - acc: 0.7649 - val_loss: 3.4816 - val_acc: 0.7775
#
# Epoch 00032: val_loss improved from 3.58266 to 3.48158, saving model to ./runs11-20190322-022352.hdf5
# Epoch 33/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.7025 - acc: 0.7653 - val_loss: 3.7937 - val_acc: 0.7600
#
# Epoch 00033: val_loss did not improve from 3.48158
# Epoch 34/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.7194 - acc: 0.7635 - val_loss: 3.7439 - val_acc: 0.7638
#
# Epoch 00034: val_loss did not improve from 3.48158
# Epoch 35/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.6024 - acc: 0.7710 - val_loss: 3.7640 - val_acc: 0.7588
#
# Epoch 00035: val_loss did not improve from 3.48158
# Epoch 36/100
# 450/450 [==============================] - 72s 161ms/step - loss: 3.4630 - acc: 0.7831 - val_loss: 3.5546 - val_acc: 0.7750
#
# Epoch 00036: val_loss did not improve from 3.48158
# Epoch 37/100
# 450/450 [==============================] - 73s 163ms/step - loss: 3.7418 - acc: 0.7639 - val_loss: 4.3389 - val_acc: 0.7262
#
# Epoch 00037: val_loss did not improve from 3.48158
# Epoch 38/100
# 450/450 [==============================] - 73s 161ms/step - loss: 3.6388 - acc: 0.7693 - val_loss: 4.2620 - val_acc: 0.7288
#
# Epoch 00038: val_loss did not improve from 3.48158
# Epoch 39/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.6790 - acc: 0.7667 - val_loss: 3.6938 - val_acc: 0.7662
#
# Epoch 00039: val_loss did not improve from 3.48158
# Epoch 40/100
# 450/450 [==============================] - 75s 167ms/step - loss: 3.6689 - acc: 0.7688 - val_loss: 3.8381 - val_acc: 0.7575
#
# Epoch 00040: val_loss did not improve from 3.48158
# Epoch 41/100
# 450/450 [==============================] - 75s 168ms/step - loss: 3.7340 - acc: 0.7640 - val_loss: 3.6421 - val_acc: 0.7688
# Epoch 00041: val_loss did not improve from 3.48158
# Epoch 42/100
# 450/450 [==============================] - 73s 163ms/step - loss: 3.5733 - acc: 0.7743 - val_loss: 3.8677 - val_acc: 0.7588
#
# Epoch 00042: val_loss did not improve from 3.48158
# Epoch 43/100
# 450/450 [==============================] - 74s 165ms/step - loss: 3.5393 - acc: 0.7767 - val_loss: 4.0963 - val_acc: 0.7412
#
# Epoch 00043: val_loss did not improve from 3.48158
# Epoch 44/100
# 450/450 [==============================] - 74s 165ms/step - loss: 3.8062 - acc: 0.7593 - val_loss: 4.3405 - val_acc: 0.7300
#
# Epoch 00044: val_loss did not improve from 3.48158
# Epoch 45/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.6673 - acc: 0.7683 - val_loss: 3.9484 - val_acc: 0.7525
#
# Epoch 00045: val_loss did not improve from 3.48158
# Epoch 46/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.5583 - acc: 0.7761 - val_loss: 3.9482 - val_acc: 0.7500
#
# Epoch 00046: val_loss did not improve from 3.48158
# Epoch 47/100
# 450/450 [==============================] - 74s 165ms/step - loss: 3.4413 - acc: 0.7840 - val_loss: 3.8463 - val_acc: 0.7575
#
# Epoch 00047: val_loss did not improve from 3.48158
# Epoch 48/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.5867 - acc: 0.7742 - val_loss: 3.6102 - val_acc: 0.7738
#
# Epoch 00048: val_loss did not improve from 3.48158
# Epoch 49/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.4427 - acc: 0.7818 - val_loss: 3.8924 - val_acc: 0.7550
#
# Epoch 00049: val_loss did not improve from 3.48158
# Epoch 50/100
# 450/450 [==============================] - 74s 165ms/step - loss: 3.5482 - acc: 0.7740 - val_loss: 3.4875 - val_acc: 0.7800
#
# Epoch 00050: val_loss did not improve from 3.48158
# Epoch 51/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.2854 - acc: 0.7935 - val_loss: 3.6627 - val_acc: 0.7700
#
# Epoch 00051: val_loss did not improve from 3.48158
# Epoch 52/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.2779 - acc: 0.7928 - val_loss: 3.8343 - val_acc: 0.7575
#
# Epoch 00052: val_loss did not improve from 3.48158
# Epoch 53/100
# 450/450 [==============================] - 76s 169ms/step - loss: 3.3025 - acc: 0.7924 - val_loss: 3.9323 - val_acc: 0.7500
#
# Epoch 00053: val_loss did not improve from 3.48158
# Epoch 54/100
# 450/450 [==============================] - 73s 162ms/step - loss: 3.2643 - acc: 0.7940 - val_loss: 3.8417 - val_acc: 0.7588
#
# Epoch 00054: val_loss did not improve from 3.48158
# Epoch 55/100
# 450/450 [==============================] - 73s 162ms/step - loss: 3.3303 - acc: 0.7911 - val_loss: 3.4611 - val_acc: 0.7825
#
# Epoch 00055: val_loss improved from 3.48158 to 3.46106, saving model to ./runs11-20190322-022352.hdf5
# Epoch 56/100
# 450/450 [==============================] - 74s 163ms/step - loss: 3.3305 - acc: 0.7894 - val_loss: 3.7657 - val_acc: 0.7650
#
# Epoch 00056: val_loss did not improve from 3.46106
# Epoch 57/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.3693 - acc: 0.7876 - val_loss: 3.3026 - val_acc: 0.7950
#
# Epoch 00057: val_loss improved from 3.46106 to 3.30259, saving model to ./runs11-20190322-022352.hdf5
# Epoch 58/100
# 450/450 [==============================] - 73s 163ms/step - loss: 3.4408 - acc: 0.7829 - val_loss: 3.1490 - val_acc: 0.8025
#
# Epoch 00058: val_loss improved from 3.30259 to 3.14904, saving model to ./runs11-20190322-022352.hdf5
# Epoch 59/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.4573 - acc: 0.7825 - val_loss: 3.5397 - val_acc: 0.7775
#
# Epoch 00059: val_loss did not improve from 3.14904
# Epoch 60/100
# 450/450 [==============================] - 74s 164ms/step - loss: 3.3556 - acc: 0.7892 - val_loss: 3.4743 - val_acc: 0.7837
#
# Epoch 00060: val_loss did not improve from 3.14904
# Epoch 61/100
# 258/450 [================>.............] - ETA: 31s - loss: 3.3727 - acc: 0.7871
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d8bb4c08ddd9> in <module>()
#      30 training_start_time = datetime.now()
#      31 model.compile(optimizer=Adam(1e-4),loss="categorical_crossentropy",metrics=["accuracy"])
# ---> 32 history = model.fit_generator(datagen.flow(train_x,train_y,batch_size=16,shuffle=True),epochs=100,verbose=1,callbacks=[model_checkpoint],shuffle=True,validation_data=datagen.flow(test_x,test_y,batch_size=16,shuffle=True))
#      33 time_spent_trianing = datetime.now() - training_start_time
#      34 print('model training complete. time spent: {}'.format(time_spent_trianing))
#
# /usr/local/lib/python3.5/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     211                 outs = model.train_on_batch(x, y,
#     212                                             sample_weight=sample_weight,
# --> 213                                             class_weight=class_weight)
#     214
#     215                 outs = to_list(outs)
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1213             ins = x + y + sample_weights
#    1214         self._make_train_function()
# -> 1215         outputs = self.train_function(ins)
#    1216         return unpack_singleton(outputs)
#    1217
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:
