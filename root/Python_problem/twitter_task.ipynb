# %% [markdown]
# # PYTHON TASK

# %% [markdown]
# The first 3 cells just set up tweepy and import the libraries

# %%
import jsonlines
from tweepy import OAuthHandler
from tweepy import API
from tweepy import Cursor
from datetime import datetime, date, time, timedelta
from collections import Counter
import sys
import json
from textwrap import TextWrapper
from tabulate import tabulate
tabulate.PRESERVE_WHITESPACE = True

# %%
consumer_key=""
consumer_secret=""
access_token=""
access_token_secret=""

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
auth_api = API(auth)

# %% [markdown]
# Here we take the tweets and put them into the JSONlines file. We create a cursor and iterate through it to get each status and store them in output.jsonl.
# At this point I am extracting 200 tweets.If more are desired then the value of no_tweet can be changes accordingly as long as it is less than 3200.

# %%
target = 'midasIIITD'
no_tweets = 100
i=0
flag=0
with jsonlines.open('output.jsonl', mode='w') as writer:
    for status in Cursor(auth_api.user_timeline, id=target,tweet_mode='extended').items():
        i=i+1
        json_string = json.dumps(status._json)
        writer.write(json_string)
        if i==no_tweets:
            break

# %% [markdown]
# Here we access the file and extract the needed attributes that is full_text,created_at,favourite_count,retweet_count and the extended_entities is used to check for the photos. Here I display 20 tweets and their statistics. Photo Count is empty in tweets with no photos

# %%
t = TextWrapper(width=80)
disp = 20
i=0
with jsonlines.open('output.jsonl') as reader:
    for obj in reader:
        i=i+1
        no_photos = 0
        obj = json.loads(obj)
        try:
            for photo in obj["extended_entities"]["media"]:
                if(photo["type"]=='photo'):
                    no_photos=no_photos+1
        except:
            no_photos = 0
        if(no_photos==0):
            no_photos=None
        print(tabulate([['Text',t.fill(obj['full_text'])],['Date and time',obj['created_at']],['Favourites',obj['favorite_count']],['Retweets',obj['retweet_count']],['Photo Count',no_photos]],headers=['Category', 'Value'],stralign = "grid"))
        if(i==disp):
            break
# Out:
#      Category                                                                         Value
# -------------  ----------------------------------------------------------------------------
# Text           @IEEEBigMM19 @ACMMM19 and 6 days left for workshop proposal in @IEEEBigMM19.
#                Contact @cchatto for any query.
# Date and time  Tue Mar 26 05:54:49 +0000 2019
# Favourites     1
# Retweets       0
# Photo Count
#      Category                                                                           Value
# -------------  ------------------------------------------------------------------------------
# Text           RT @IEEEBigMM19: Hurry Up! 6 Days left for Abstract Submission in @ACMMM19  45
#                Days left for Regular Paper Submission in @IEEEBigMM19 .  He…
# Date and time  Tue Mar 26 05:50:10 +0000 2019
# Favourites     0
# Retweets       3
# Photo Count
#      Category                                                                            Value
# -------------  -------------------------------------------------------------------------------
# Text           Congratulations @midasIIITD students Simra Shahid @Simcyy and Nilay Shrivastava
#                @NilayShri on getting selected for a research internship at Adobe in this
#                summer.   #MIDAS #Achievment #Research #Summer #Internship
#                https://t.co/WdF663EB5y
# Date and time  Mon Mar 25 13:01:57 +0000 2019
# Favourites     14
# Retweets       1
# Photo Count    2
#      Category                                                                            Value
# -------------  -------------------------------------------------------------------------------
# Text           The last date for submitting a solution for the @midasIIITD internship task is
#                26th March midnight. We will not accept solutions submitted after the deadline.
#                Thus, if you have not submitted your solution yet then kindly do so before the
#                deadline.  #Summer #Research #Internship
# Date and time  Sun Mar 24 18:44:01 +0000 2019
# Favourites     8
# Retweets       3
# Photo Count
#      Category                                                                      Value
# -------------  -------------------------------------------------------------------------
# Text           RT @IIITDelhi: @IIITDelhi invites application from Foreign
#                Nationals/PIOs/NRIs/OCIs for admission to its https://t.co/u6kIuhIrGM and
#                https:…
# Date and time  Sun Mar 24 18:26:02 +0000 2019
# Favourites     0
# Retweets       4
# Photo Count
#      Category                                                                            Value
# -------------  -------------------------------------------------------------------------------
# Text           One more week is left to submit the workshop proposal to @IEEEBigMM19.  Looking
#                forward to your submission. For any query, contact workshop co-chair Dr.
#                Chiranjoy Chattopadhyay @cchatto or TPC co-chair @RatnRajiv
# Date and time  Sun Mar 24 11:34:27 +0000 2019
# Favourites     4
# Retweets       0
# Photo Count
#      Category                                                                           Value
# -------------  ------------------------------------------------------------------------------
# Text           RT @IEEEBigMM19: We are honored to have Dr. Chang Wen Chen (Chinese University
#                Hong Kong @CUHKofficial ) and Dr. Roger Zimmermann (National…
# Date and time  Sun Mar 24 06:23:37 +0000 2019
# Favourites     0
# Retweets       5
# Photo Count
#      Category                                                                      Value
# -------------  -------------------------------------------------------------------------
# Text           RT @IEEEBigMM19: Distinguished researchers Dr. Rajiv Ratn Shah @RatnRajiv
#                (@IIITDelhi , @midasIIITD ), Dr. Jianquan Liu (NEC Japan) and Dr.…
# Date and time  Sun Mar 24 06:23:14 +0000 2019
# Favourites     0
# Retweets       3
# Photo Count
#      Category                                                                        Value
# -------------  ---------------------------------------------------------------------------
# Text           @IEEEBigMM19 is also available on Facebook now.  LIKE its Facebook page
#                https://t.co/B3Q0zmmzXb  to get the regular updates.  Check more details at
#                https://t.co/w9ZymoPisk   #IEEE #BigMM19 #Big #Multimedia #Singapore
# Date and time  Wed Mar 20 08:19:24 +0000 2019
# Favourites     1
# Retweets       1
# Photo Count
#      Category                                                                        Value
# -------------  ---------------------------------------------------------------------------
# Text           RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#                https://t.co/I4vqf8FE6K …   When: Sep 11, 2019 - Sep 13, 201…
# Date and time  Wed Mar 20 02:40:07 +0000 2019
# Favourites     0
# Retweets       5
# Photo Count
#      Category                                                                          Value
# -------------  -----------------------------------------------------------------------------
# Text           BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#                https://t.co/oUq2G0UgKN  When: Sep 11, 2019 - Sep 13, 2019 Where: Singapore
#                Submission Deadline: Apr 1, 2019 Notification Due: Apr 10, 2019  #IEEE #BigMM
#                #Workshop #Proposal #Singapore #Multimedia
# Date and time  Mon Mar 18 02:27:47 +0000 2019
# Favourites     6
# Retweets       3
# Photo Count
#      Category                                                                             Value
# -------------  --------------------------------------------------------------------------------
# Text           Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs,
#                @MADAIguy and @RatnRajiv for getting their paper titled, "SNAP-BATNET: Cascading
#                Author Profiling and Social Network Graphs for Suicide Ideation Detection on
#                Social Media", accepted at @NAACLHLT SRW.
# Date and time  Sun Mar 17 14:22:04 +0000 2019
# Favourites     15
# Retweets       4
# Photo Count
#      Category                                                                           Value
# -------------  ------------------------------------------------------------------------------
# Text           We have emailed the task details to all shortlisted candidates for @midasIIITD
#                internship. Kindly check the same.   If you are one of the shortlisted
#                candidates and have not received the email then check your SPAM first before
#                approaching.   #MIDAS #Summer #Research #Internship
# Date and time  Sat Mar 16 14:06:56 +0000 2019
# Favourites     7
# Retweets       0
# Photo Count
#      Category                                                                            Value
# -------------  -------------------------------------------------------------------------------
# Text           IEEE BigMM 2019 - Call for Workshop Proposals.   Contact @midasIIITD @RatnRajiv
#                @debanjanbhucs if you have any query.   Deadlines:  - Proposals due: April 1,
#                2019 - Acceptance notification: April 10, 2019  Further information: - Webpage:
#                https://t.co/5XX5Wyxp5T  #IEEE #BigMM19
# Date and time  Sat Mar 16 09:20:29 +0000 2019
# Favourites     1
# Retweets       1
# Photo Count
#      Category                                                                         Value
# -------------  ----------------------------------------------------------------------------
# Text           Congratulations! Arijit, Ramit, @debanjanbhucs @RatnRajiv for your @NAACLHLT
#                @naacl SRW 2019 paper, "Speak Up, Fight Back! Detection of Social Media
#                Disclosures of Sexual Harassment".   Check more details at
#                https://t.co/i6eAHg7gcN  #MeToo #Student #Research  #Paper #NAACL
# Date and time  Sat Mar 16 09:14:58 +0000 2019
# Favourites     7
# Retweets       2
# Photo Count
#      Category                                                                           Value
# -------------  ------------------------------------------------------------------------------
# Text           We will be releasing a very interesting task to shortlisted candidates for the
#                internship at @midasIIITD today. You will be having 10 days to solve the same.
#                You will get a detailed email on the task and submission instruction today.
#                Looking forward to your out of box solution.
# Date and time  Sat Mar 16 05:13:14 +0000 2019
# Favourites     7
# Retweets       2
# Photo Count
#      Category                                                                       Value
# -------------  --------------------------------------------------------------------------
# Text           RT @hcdiiitd: Last day to register for #PortfolioCreationinDesign Workshop
#                Indraprastha Institute of Information Technology, Delhi on 15th…
# Date and time  Wed Mar 13 17:09:44 +0000 2019
# Favourites     0
# Retweets       2
# Photo Count
#      Category                                                                            Value
# -------------  -------------------------------------------------------------------------------
# Text           @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm @Benoit_Huet
#                @RatnRajiv @kelkalot  We need to clearly mention abstract and final submission
#                deadlines at https://t.co/U7DTNNyw87  Currently, we have just mentioned 1st
#                April as the regular paper submission deadline. Kindly update.   #ACMMM19 #Nice
#                #Multimedia https://t.co/ocOCrlFHLH
# Date and time  Wed Mar 13 04:11:24 +0000 2019
# Favourites     1
# Retweets       0
# Photo Count    1
#      Category                                                                             Value
# -------------  --------------------------------------------------------------------------------
# Text           RT @ACMMM19: The paper deadline is approaching. 1 April abstract is due. Authors
#                will have until 8 April to upload the final PDF version of…
# Date and time  Wed Mar 13 04:06:04 +0000 2019
# Favourites     0
# Retweets       13
# Photo Count
#      Category                                                                           Value
# -------------  ------------------------------------------------------------------------------
# Text           RT @kaggle: Bookmark this amazing library of image augmentations 😵 by #Kaggle
#                Masters @AlBuslaev @creaf @viglovikov and @cvtalks | https://…
# Date and time  Tue Mar 12 17:43:44 +0000 2019
# Favourites     0
# Retweets       67
# Photo Count
